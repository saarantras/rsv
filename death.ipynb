# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# Load and inspect the data

# %%
tab=pd.read_csv("Provisional_Percent_of_Deaths_for_COVID-19,_Influenza,_and_RSV_by_Select_Characteristics_20251225.csv.gz",compression="gzip").drop_duplicates()
tab
# Out:
#        data_as_of  start_date    end_date    group  year  month  mmwr_week  \
# 0      2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 1      2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 2      2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 3      2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 4      2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# ...           ...         ...         ...      ...   ...    ...        ...
# 19867  2025-12-17  2019-12-08  2019-12-14  By Week  2019     12         50
# 19868  2025-12-17  2019-12-15  2019-12-21  By Week  2019     12         51
# 19869  2025-12-17  2019-12-15  2019-12-21  By Week  2019     12         51
# 19870  2025-12-17  2019-12-22  2019-12-28  By Week  2019     12         52
# 19871  2025-12-17  2019-12-22  2019-12-28  By Week  2019     12         52
#
#       weekending_date          state demographic_type  demographic_values  \
# 0          2020-01-04  United States   Race/Ethnicity           AI/AN, NH
# 1          2020-01-04  United States   Race/Ethnicity           Black, NH
# 2          2020-01-04  United States   Race/Ethnicity           White, NH
# 3          2020-01-04  United States   Race/Ethnicity  Multiple/Other, NH
# 4          2020-01-04  United States   Race/Ethnicity       Not Available
# ...               ...            ...              ...                 ...
# 19867      2019-12-14  United States              Sex                Male
# 19868      2019-12-21  United States              Sex              Female
# 19869      2019-12-21  United States              Sex                Male
# 19870      2019-12-28  United States              Sex              Female
# 19871      2019-12-28  United States              Sex                Male
#
#        pathogen deaths total_deaths  percent_deaths provisional  \
# 0      Combined    NaN          384             NaN         NaN
# 1      Combined     47        7,498            0.63         NaN
# 2      Combined    314       45,526            0.69         NaN
# 3      Combined    NaN          292             NaN         NaN
# 4      Combined      0            0             NaN         NaN
# ...         ...    ...          ...             ...         ...
# 19867  COVID-19      0       29,238            0.00         NaN
# 19868  COVID-19      0       28,228            0.00         NaN
# 19869  COVID-19      0       29,197            0.00         NaN
# 19870  COVID-19      0       28,365            0.00         NaN
# 19871  COVID-19      0       30,097            0.00         NaN
#
#                                               suppressed
# 0      One or more data cells have counts between 1-9...
# 1                                                    NaN
# 2                                                    NaN
# 3      One or more data cells have counts between 1-9...
# 4                                                    NaN
# ...                                                  ...
# 19867                                                NaN
# 19868                                                NaN
# 19869                                                NaN
# 19870                                                NaN
# 19871                                                NaN
#
# [19872 rows x 17 columns]

# %% [markdown]
# Not immediately clear what some of the catrgorical fields mean, let us examine them more closely...

# %%
tab["group"].unique()
# Out:
# array(['By Week'], dtype=object)

# %%
tab["demographic_type"].unique()
# Out:
# array(['Race/Ethnicity', 'Age Group', 'Sex'], dtype=object)

# %%
tab["pathogen"].unique()
# Out:
# array(['Combined', 'COVID-19', 'Influenza', 'RSV'], dtype=object)

# %%
tab["group"].unique()
# Out:
# array(['By Week'], dtype=object)

# %% [markdown]
# Quick spot-check:

# %%
tab[(tab["mmwr_week"]==1)&(tab["year"]==2020)&(tab["demographic_values"]=="65+ years")]
# Out:
#        data_as_of  start_date    end_date    group  year  month  mmwr_week  \
# 9525   2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 10765  2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 11800  2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
# 13145  2025-12-17  2019-12-29  2020-01-04  By Week  2020      1          1
#
#       weekending_date          state demographic_type demographic_values  \
# 9525       2020-01-04  United States        Age Group          65+ years
# 10765      2020-01-04  United States        Age Group          65+ years
# 11800      2020-01-04  United States        Age Group          65+ years
# 13145      2020-01-04  United States        Age Group          65+ years
#
#         pathogen deaths total_deaths  percent_deaths provisional suppressed
# 9525    COVID-19      0       44,657            0.00         NaN        NaN
# 10765   Combined    239       44,657            0.54         NaN        NaN
# 11800  Influenza    227       44,657            0.51         NaN        NaN
# 13145        RSV     12       44,657            0.03         NaN        NaN

# %% [markdown]
# Confirms what data description website suggests : 'deaths' is what we want.

# %% [markdown]
# Subset

# %%
relevant=tab[(tab["demographic_type"]=="Age Group") & (tab["pathogen"]=="RSV")][["year","mmwr_week","deaths","suppressed","demographic_values"]]

# %%
relevant
# Out:
#        year  mmwr_week deaths  \
# 13145  2020          1     12
# 13146  2020          2     13
# 13147  2020          3     21
# 13148  2020          4     16
# 13149  2020          5     12
# ...     ...        ...    ...
# 15312  2023         45    NaN
# 15313  2023         46    NaN
# 15314  2023         47    NaN
# 15315  2023         48    NaN
# 15316  2023         49    NaN
#
#                                               suppressed demographic_values
# 13145                                                NaN          65+ years
# 13146                                                NaN          65+ years
# 13147                                                NaN          65+ years
# 13148                                                NaN          65+ years
# 13149                                                NaN          65+ years
# ...                                                  ...                ...
# 15312  One or more data cells have counts between 1-9...         0-17 years
# 15313  One or more data cells have counts between 1-9...         0-17 years
# 15314  One or more data cells have counts between 1-9...         0-17 years
# 15315  One or more data cells have counts between 1-9...         0-17 years
# 15316  One or more data cells have counts between 1-9...         0-17 years
#
# [1242 rows x 5 columns]

# %%
relevant["demographic_values"].unique()
# Out:
# array(['65+ years', '0-17 years', '18-64 years'], dtype=object)

# %% [markdown]
# looks like some are suppressed due to small amount of data. Let us remove missing data.

# %%
relevant=relevant[~relevant["deaths"].isna()]
relevant=relevant.drop(columns=["suppressed"])
relevant
# Out:
#        year  mmwr_week deaths demographic_values
# 13145  2020          1     12          65+ years
# 13146  2020          2     13          65+ years
# 13147  2020          3     21          65+ years
# 13148  2020          4     16          65+ years
# 13149  2020          5     12          65+ years
# ...     ...        ...    ...                ...
# 15307  2023         40      0         0-17 years
# 15308  2023         41      0         0-17 years
# 15309  2023         42      0         0-17 years
# 15310  2023         43      0         0-17 years
# 15311  2023         44      0         0-17 years
#
# [716 rows x 4 columns]

# %% [markdown]
# Similar to hispotalization analysis, let us subset to age cohorts who could be affected by changes in RSV vaccine.

# %%
relevant=relevant.rename({"demographic_values":"Age Category"},axis=1)

# %%
relevant["Age Category"].unique()
# Out:
# array(['65+ years', '0-17 years', '18-64 years'], dtype=object)

# %% [markdown]
# Spot-check: year x week x age should be unique

# %%
assert len(relevant[["year","mmwr_week","Age Category"]].drop_duplicates()) == len(relevant)

# %% [markdown]
# Cast deaths to int

# %%
relevant['deaths'] = relevant['deaths'].astype('int64')

# %% [markdown]
# Generate summary

# %%
summary = (
    relevant
    .groupby(["year", "Age Category"], as_index=False)
    .agg(Total_Deaths=("deaths", "sum"),
         Weeks_Observed=("mmwr_week", "nunique"),
))
summary
# Out:
#     year Age Category  Total_Deaths  Weeks_Observed
# 0   2018   0-17 years             0              31
# 1   2018  18-64 years             0              28
# 2   2018    65+ years           124              30
# 3   2019   0-17 years             0              26
# 4   2019  18-64 years             0              36
# 5   2019    65+ years            83              27
# 6   2020   0-17 years             0              41
# 7   2020  18-64 years             0              33
# 8   2020    65+ years           187              39
# 9   2021   0-17 years             0              34
# 10  2021  18-64 years             0              32
# 11  2021    65+ years            84              25
# 12  2022   0-17 years             0              18
# 13  2022  18-64 years            10              29
# 14  2022    65+ years           420              17
# 15  2023   0-17 years             0              35
# 16  2023  18-64 years            32              32
# 17  2023    65+ years           498              24
# 18  2024   0-17 years             0              34
# 19  2024  18-64 years            77              30
# 20  2024    65+ years           658              25
# 21  2025   0-17 years             0              37
# 22  2025  18-64 years             0              25
# 23  2025    65+ years           415              28

# %% [markdown]
# Cast year to int

# %%
summary["year"] = summary["year"].astype("int")
summary
# Out:
#     year Age Category  Total_Deaths  Weeks_Observed
# 0   2018   0-17 years             0              31
# 1   2018  18-64 years             0              28
# 2   2018    65+ years           124              30
# 3   2019   0-17 years             0              26
# 4   2019  18-64 years             0              36
# 5   2019    65+ years            83              27
# 6   2020   0-17 years             0              41
# 7   2020  18-64 years             0              33
# 8   2020    65+ years           187              39
# 9   2021   0-17 years             0              34
# 10  2021  18-64 years             0              32
# 11  2021    65+ years            84              25
# 12  2022   0-17 years             0              18
# 13  2022  18-64 years            10              29
# 14  2022    65+ years           420              17
# 15  2023   0-17 years             0              35
# 16  2023  18-64 years            32              32
# 17  2023    65+ years           498              24
# 18  2024   0-17 years             0              34
# 19  2024  18-64 years            77              30
# 20  2024    65+ years           658              25
# 21  2025   0-17 years             0              37
# 22  2025  18-64 years             0              25
# 23  2025    65+ years           415              28

# %% [markdown]
# Subset to relevant years (2018+)

# %%
summary=summary[summary["year"]>=2018]

# %%
summary
# Out:
#     year Age Category  Total_Deaths  Weeks_Observed
# 0   2018   0-17 years             0              31
# 1   2018  18-64 years             0              28
# 2   2018    65+ years           124              30
# 3   2019   0-17 years             0              26
# 4   2019  18-64 years             0              36
# 5   2019    65+ years            83              27
# 6   2020   0-17 years             0              41
# 7   2020  18-64 years             0              33
# 8   2020    65+ years           187              39
# 9   2021   0-17 years             0              34
# 10  2021  18-64 years             0              32
# 11  2021    65+ years            84              25
# 12  2022   0-17 years             0              18
# 13  2022  18-64 years            10              29
# 14  2022    65+ years           420              17
# 15  2023   0-17 years             0              35
# 16  2023  18-64 years            32              32
# 17  2023    65+ years           498              24
# 18  2024   0-17 years             0              34
# 19  2024  18-64 years            77              30
# 20  2024    65+ years           658              25
# 21  2025   0-17 years             0              37
# 22  2025  18-64 years             0              25
# 23  2025    65+ years           415              28

# %% [markdown]
# Generate tables

# %%
from pathlib import Path

# %%
out_dir = Path("tables_death_svg")
out_dir.mkdir(parents=True, exist_ok=True)



for age_cat, sub in summary.groupby("Age Category", sort=True):
    sub = sub.sort_values("year")[["year", "Total_Deaths", "Weeks_Observed"]]

    # Convert to strings for stable table rendering
    cell_text = [
        [str(int(y)), f"{rate:.1f}", str(int(w))]
        for y, rate, w in sub.itertuples(index=False, name=None)
    ]
    col_labels = ["year", "Total_Deaths", "Weeks_Observed"]

    # Figure sizing: scale height with number of rows
    nrows = len(cell_text) + 1
    fig_h = max(1.5, 0.35 * nrows)
    fig, ax = plt.subplots(figsize=(7.0, fig_h))
    ax.axis("off")

    tbl = ax.table(
        cellText=cell_text,
        colLabels=col_labels,
        loc="center",
        cellLoc="center",
        colLoc="center",
    )

    tbl.auto_set_font_size(False)
    tbl.set_fontsize(10)
    tbl.scale(1.0, 1.25)

    for (row, col), cell in tbl.get_celld().items():
        if row == 0:
            continue  # header
        year_val = sub.iloc[row - 1]["year"]
        if year_val == 2023:
            cell.set_text_props(weight="bold")

    ax.set_title(f"Annual RSV mortality — {age_cat}", pad=12)

    # Minimal filename cleanup inline
    fname_age = re.sub(r"[^\w\-]+", "_", age_cat).strip("_")
    fname = out_dir / f"annual_rsv_table_{fname_age}.svg"

    fig.savefig(fname, format="svg", bbox_inches="tight")
    plt.close(fig)

print(f"Wrote SVG tables to: {out_dir.resolve()}")
# Out:
# Wrote SVG tables to: /Users/mcnoon/rsv/tables_death_svg
